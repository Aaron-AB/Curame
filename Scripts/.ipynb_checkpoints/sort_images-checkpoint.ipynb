# %%
import pandas as pd
df = pd.read_csv('metadata.csv')
df = df[df['diagnostic'] == "BCC"]

# %%
import os 
import sys

img_ids = df['img_id']
print(img_ids)
# Out:
# 1         PAT_46_881_939.png
# 4       PAT_684_1302_588.png
# 6       PAT_778_1471_835.png
# 7        PAT_117_179_983.png
# 11      PAT_967_1827_247.png
#                 ...
# 2280    PAT_681_1299_458.png
# 2282     PAT_136_203_436.png
# 2291     PAT_273_421_905.png
# 2294      PAT_46_880_140.png
# 2296     PAT_326_690_823.png
# Name: img_id, Length: 845, dtype: object

# %%
import shutil

def move_file(filePath, newFilePath, img_ids):
    if not os.path.isdir(newFilePath):
        os.mkdir(newFilePath)
        
    files = os.listdir(filePath)
    
    for fileName in img_ids:
        for f in files:
            if fileName == f:
                print(f)
#shutil.move(source+f, destination)

source = "E:/Data/imgs_part_1/imgs_part_1"
source2 = "E:/Data/imgs_part_1/imgs_part_2"
source3 = "E:/Data/imgs_part_1/imgs_part_3"
destination = "E:/Data/BCC"

move_file(source, destination, img_ids)
move_file(source2, destination, img_ids)
move_file(source2, destination, img_ids)
# Out:
# PAT_46_881_939.png
# PAT_117_179_983.png
# PAT_38_54_234.png
# PAT_106_159_325.png
# PAT_435_854_68.png
# PAT_42_58_13.png
# PAT_302_651_529.png
# PAT_134_201_587.png
# PAT_79_120_532.png
# PAT_394_1562_579.png
# PAT_265_406_276.png
# PAT_53_1370_245.png
# PAT_479_919_97.png
# PAT_288_441_312.png
# PAT_241_367_89.png
# PAT_98_152_562.png
# PAT_409_812_974.png
# PAT_430_848_476.png
# PAT_419_832_706.png
# PAT_55_84_506.png
# PAT_241_367_374.png
# PAT_461_895_72.png
# PAT_426_842_458.png
# PAT_168_1486_97.png
# PAT_441_861_415.png
# PAT_413_819_268.png
# PAT_118_180_386.png
# PAT_63_1075_498.png
# PAT_483_925_716.png
# PAT_358_738_837.png
# PAT_514_967_300.png
# PAT_330_698_211.png
# PAT_280_431_466.png
# PAT_396_796_394.png
# PAT_34_47_108.png
# PAT_162_252_773.png
# PAT_267_412_275.png
# PAT_458_891_709.png
# PAT_466_903_893.png
# PAT_82_125_365.png
# PAT_478_916_806.png
# PAT_206_312_760.png
# PAT_167_258_711.png
# PAT_54_83_405.png
# PAT_373_761_708.png
# PAT_228_348_535.png
# ...
